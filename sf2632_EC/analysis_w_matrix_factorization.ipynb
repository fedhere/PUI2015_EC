# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('yelp_data.csv')
df.columns
# Out:
# Index([u'Unnamed: 0', u'restaurants', u'bars', u'coffee & tea',
#        u'health & medical', u'arts & entertainment', u'fitness & instruction',
#        u'grocery', u'education', u'haircut', u'boutique', u'PjAreaCode'],
#       dtype='object')

# %%
df = df.rename(columns={'Unnamed: 0': 'Neighborhood'})
activities = df.columns.tolist()
activities.pop(0)
activities.pop(-1)
activities
# Out:
# ['restaurants',
#  'bars',
#  'coffee & tea',
#  'health & medical',
#  'arts & entertainment',
#  'fitness & instruction',
#  'grocery',
#  'education',
#  'haircut',
#  'boutique']

# %%
# source: http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/
def matrix_factorization(R, P, Q, K, steps=5000, alpha=0.0002, beta=0.02):
    Q = Q.T
    for step in xrange(steps):
        for i in xrange(len(R)):
            for j in xrange(len(R[i])):
                if R[i][j] > 0:
                    eij = R[i][j] - np.dot(P[i,:],Q[:,j])
                    for k in xrange(K):
                        P[i][k] = P[i][k] + alpha * (2 * eij * Q[k][j] - beta * P[i][k])
                        Q[k][j] = Q[k][j] + alpha * (2 * eij * P[i][k] - beta * Q[k][j])
        eR = np.dot(P,Q)
        e = 0
        for i in xrange(len(R)):
            for j in xrange(len(R[i])):
                if R[i][j] > 0:
                    e = e + pow(R[i][j] - np.dot(P[i,:],Q[:,j]), 2)
                    for k in xrange(K):
                        e = e + (beta/2) * ( pow(P[i][k],2) + pow(Q[k][j],2) )
        if e < 0.001:
            break
    return P, Q.T

# %%
R = np.array(df[activities])

N = len(R)
M = len(R[0])
K = 2

P = np.random.rand(N,K)
Q = np.random.rand(M,K)

nP, nQ = matrix_factorization(R, P, Q, K)
nR = np.dot(nP, nQ.T)

# %%
df_factorized = pd.DataFrame(columns=df.columns.tolist())
df_factorized['Neighborhood'] = df['Neighborhood']
for i in df_factorized.index:
    count = 0
    for act in activities:
        df_factorized.loc[i,act] = nR[i,count]
        count += 1
df_factorized['PjAreaCode'] = df['PjAreaCode']
df_factorized
# Out:
#                                          Neighborhood restaurants      bars  \
# 0                                     Upper West Side    3.623001  3.398488
# 1                                     Stuyvesant Town    3.535625  3.305909
# 2                      SoHo, TriBeCa and Little Italy    3.720195   3.48995
# 3                                             Clinton    3.894155  3.621124
# 4               Theater District and Garment District    3.826342   3.53001
# 5                                         East Harlem    2.805529  2.582226
# 6                                  Washington Heights    2.683195  2.514888
# 7                                          Turtle Bay    3.768779  3.517744
# 8                                            Gramercy    3.650928  3.370835
# 9                                     Upper East Side     3.69838  3.548866
# 10                                  Greenwich Village     3.85919   3.58274
# 11                                    Lower East Side    3.715421  3.393806
# 12                                          Chinatown    3.506237  3.305685
# 13                                             Harlem    3.022892  2.771071
# 14                                       East Village    3.907672  3.660484
# 15        Chelsea, Flatiron District and Union Square    4.296135  4.044279
# 16                           Murray Hill and Kips Bay    3.768704  3.517768
# 17           Financial District and Battery Park City    3.423702  3.178793
# 18                                Morningside Heights    3.192578  2.927578
# 19                                       Clinton Hill    3.090535  2.833133
# 20                                      Crown Heights    2.787934  2.520041
# 18   2.48868  2.460848  2.954857   2.42457       MN09
# 19  2.406556  2.383999  2.856403  2.348936       BK69
# 20  2.065349  2.224461  2.412657  2.195104       BK61
# 21  2.849265  2.485498  3.455066  2.442598       BK09
# 22  3.099635  2.586689  3.784124  2.539536       BK37
# 23   2.20682  2.382354  2.576719  2.351008       BK77
# 24  2.753617  2.635393  3.288409  2.594893       BK72
# 25  2.673529  2.489861  3.207725  2.450256       BK68
# 26  2.723554  2.404465  3.296409  2.363575       BK38
# 27  2.182372  2.218048  2.578124  2.186482       BK75
# 28  2.640181  2.480442  3.163015  2.441419       BK76
# 29  2.507227  2.485681  2.975467  2.449159       BK90
# 30  2.399986  2.365983  2.851104  2.330969       BK33
# 31  2.683447  2.452255  3.229798   2.41231       BK64

# %%
df_dist = pd.DataFrame(columns=['Neighborhood1','Neighborhood2','Cosine_Distance','Similarity'])
count = 0
for i in df_factorized.index:
    nh1 = df_factorized.iloc[i].tolist()
    nh1.pop(-1)
    name1 = nh1.pop(0)
    for j in df_factorized.index:
        if not j==i:
            count += 1
            nh2 = df_factorized.iloc[j].tolist()
            nh2.pop(-1)
            name2 = nh2.pop(0)
            row = [name1,name2,distance.cosine(nh1,nh2),1-distance.cosine(nh1,nh2)]
            df_dist.loc[count] = row
df_dist
# Out:
#         Neighborhood1                                      Neighborhood2  \
# 1     Upper West Side                                    Stuyvesant Town
# 2     Upper West Side                     SoHo, TriBeCa and Little Italy
# 3     Upper West Side                                            Clinton
# 4     Upper West Side              Theater District and Garment District
# 5     Upper West Side                                        East Harlem
# 6     Upper West Side                                 Washington Heights
# 7     Upper West Side                                         Turtle Bay
# 8     Upper West Side                                           Gramercy
# 9     Upper West Side                                    Upper East Side
# 10    Upper West Side                                  Greenwich Village
# 11    Upper West Side                                    Lower East Side
# 12    Upper West Side                                          Chinatown
# 13    Upper West Side                                             Harlem
# 14    Upper West Side                                       East Village
# 15    Upper West Side        Chelsea, Flatiron District and Union Square
# 16    Upper West Side                           Murray Hill and Kips Bay
# 17    Upper West Side           Financial District and Battery Park City
# 18    Upper West Side                                Morningside Heights
# 19    Upper West Side                                       Clinton Hill
# 20    Upper West Side                                      Crown Heights
# 21    Upper West Side                   Brooklyn Heights and Cobble Hill
# 22    Upper West Side                             Park Slope and Gowanus
# 23    Upper West Side                                           Bushwick
# 24    Upper West Side                                       Williamsburg
# 25    Upper West Side                                        Fort Greene
# 26    Upper West Side  Downtown Brooklyn, DUMBO, Vinegar Hill and Boe...
# 27    Upper West Side                                 Bedford-Stuyvesant
# 28    Upper West Side                                         Greenpoint
# 29    Upper West Side                                  East Williamsburg
# 30    Upper West Side                       Carroll Gardens and Red Hook
# ..                ...                                                ...
# 963  Prospect Heights                                    Stuyvesant Town
# 964  Prospect Heights                     SoHo, TriBeCa and Little Italy
# 965  Prospect Heights                                            Clinton
# 966  Prospect Heights              Theater District and Garment District
# 967  Prospect Heights                                        East Harlem
# 968  Prospect Heights                                 Washington Heights
# 969  Prospect Heights                                         Turtle Bay
# 970  Prospect Heights                                           Gramercy
# 971  Prospect Heights                                    Upper East Side
# 972  Prospect Heights                                  Greenwich Village
# 973  Prospect Heights                                    Lower East Side
    for j in df_dist[df_dist.Neighborhood1==i].index:
        df_dist.loc[j,'Similarity'] = (df_dist.loc[j,'Similarity']-loc_min)/(loc_max-loc_min)
df_dist
# Out:
#         Neighborhood1                                      Neighborhood2  \
# 1     Upper West Side                                    Stuyvesant Town
# 2     Upper West Side                     SoHo, TriBeCa and Little Italy
# 3     Upper West Side                                            Clinton
# 4     Upper West Side              Theater District and Garment District
# 5     Upper West Side                                        East Harlem
# 6     Upper West Side                                 Washington Heights
# 7     Upper West Side                                         Turtle Bay
# 8     Upper West Side                                           Gramercy
# 9     Upper West Side                                    Upper East Side
# 10    Upper West Side                                  Greenwich Village
# 11    Upper West Side                                    Lower East Side
# 12    Upper West Side                                          Chinatown
# 13    Upper West Side                                             Harlem
# 14    Upper West Side                                       East Village
# 15    Upper West Side        Chelsea, Flatiron District and Union Square
# 16    Upper West Side                           Murray Hill and Kips Bay
# 17    Upper West Side           Financial District and Battery Park City
# 18    Upper West Side                                Morningside Heights
# 19    Upper West Side                                       Clinton Hill
# 20    Upper West Side                                      Crown Heights
# 21    Upper West Side                   Brooklyn Heights and Cobble Hill
# 22    Upper West Side                             Park Slope and Gowanus
# 23    Upper West Side                                           Bushwick
# 24    Upper West Side                                       Williamsburg
# 25    Upper West Side                                        Fort Greene
# 26    Upper West Side  Downtown Brooklyn, DUMBO, Vinegar Hill and Boe...
# 27    Upper West Side                                 Bedford-Stuyvesant
# 28    Upper West Side                                         Greenpoint
# 29    Upper West Side                                  East Williamsburg
# 30    Upper West Side                       Carroll Gardens and Red Hook
# ..                ...                                                ...
# 963  Prospect Heights                                    Stuyvesant Town
# 964  Prospect Heights                     SoHo, TriBeCa and Little Italy
# 965  Prospect Heights                                            Clinton
# 966  Prospect Heights              Theater District and Garment District
# 967  Prospect Heights                                        East Harlem
# 968  Prospect Heights                                 Washington Heights
# 969  Prospect Heights                                         Turtle Bay
# 970  Prospect Heights                                           Gramercy
# 971  Prospect Heights                                    Upper East Side
# 972  Prospect Heights                                  Greenwich Village
# 973  Prospect Heights                                    Lower East Side
# 974  Prospect Heights                                          Chinatown
# 975  Prospect Heights                                             Harlem
# 976  Prospect Heights                                       East Village
# 977  Prospect Heights        Chelsea, Flatiron District and Union Square
# 978  Prospect Heights                           Murray Hill and Kips Bay
# 979  Prospect Heights           Financial District and Battery Park City
# 980  Prospect Heights                                Morningside Heights
# 981  Prospect Heights                                       Clinton Hill
# 982  Prospect Heights                                      Crown Heights
# 983  Prospect Heights                   Brooklyn Heights and Cobble Hill
# 984  Prospect Heights                             Park Slope and Gowanus
# 985  Prospect Heights                                           Bushwick
# 986  Prospect Heights                                       Williamsburg
# 987  Prospect Heights                                        Fort Greene
# 988  Prospect Heights  Downtown Brooklyn, DUMBO, Vinegar Hill and Boe...
# 989  Prospect Heights                                 Bedford-Stuyvesant
# 990  Prospect Heights                                         Greenpoint
# 991  Prospect Heights                                  East Williamsburg
# 992  Prospect Heights                       Carroll Gardens and Red Hook
#
#      Cosine_Distance  Similarity
# 1       3.382848e-05    0.992830
# 2       2.288107e-08    1.000000
# 3       2.513075e-04    0.946700
# 4       9.198563e-04    0.804896
# 5       1.197567e-03    0.745991
# 6       2.141228e-06    0.999551
# 7       8.103212e-05    0.982817
# 8       8.343480e-04    0.823033
# 9       1.655951e-03    0.648764
# 10      3.549512e-04    0.924717
# 11      2.360406e-03    0.499343
# 12      8.407842e-05    0.982171
# 13      1.766546e-03    0.625305
# 14      6.205235e-06    0.998689
# 15      4.145702e-05    0.991211
# 16      8.016070e-05    0.983002
# 17      3.474986e-04    0.926297
# 18      1.716333e-03    0.635956
# 19      1.763574e-03    0.625936
# 20      4.616126e-03    0.020885
# 21      8.515925e-06    0.998199
# 22      1.103126e-04    0.976607
# 23      4.714592e-03    0.000000
# 24      9.822846e-04    0.791654
# 25      5.259869e-04    0.888439
# 26      4.311820e-05    0.990859
# 27      2.493711e-03    0.471068
# 28      6.569223e-04    0.860666
# 29      1.784081e-03    0.621586
# 30      1.639696e-03    0.652211
# ..               ...         ...
# 963     1.278476e-04    0.962205
# 964     2.983969e-04    0.911141
# 965     1.613706e-06    1.000000
# 966     1.744495e-04    0.948252
# 967     3.057449e-04    0.908941
# 968     2.452268e-04    0.927061
# 969     6.595783e-05    0.980735
# 970     1.383828e-04    0.959050
# 971     3.341558e-03    0.000000
# 972     2.949371e-06    0.999600
# 973     9.902126e-04    0.704007
# 974     6.912330e-04    0.793524
# 975     6.206013e-04    0.814671
# 976     2.140966e-04    0.936381
# 977     5.551196e-04    0.834277
# 978     6.674851e-05    0.980498
# 979     2.305910e-06    0.999793
# 980     5.909784e-04    0.823541
# 981     6.188396e-04    0.815199
# 982     2.584091e-03    0.226790
# 983     2.017788e-04    0.940069
# 984     7.631213e-04    0.772000
# 985     2.657931e-03    0.204682
# 986     2.022202e-04    0.939937
# 987     3.378004e-05    0.990369
# 988     1.114453e-04    0.967116
# 989     1.077230e-03    0.677954
# 990     7.239483e-05    0.978808
# 991     6.310152e-04    0.811553
# 992     5.463577e-04    0.836900
#
# [992 rows x 4 columns]

# %%
df_weighted = pd.DataFrame(columns=df.columns.tolist())
df_weighted['Neighborhood'] = df['Neighborhood']
row = -1
for i in df_dist.Neighborhood1.unique():
    j = df_dist[(df_dist.Neighborhood1==i)&(df_dist.Similarity==1.0)]['Neighborhood2']
    j = j.tolist()[0]
    row = df[df.Neighborhood==i].index.values[0]
    row_sim = df[df.Neighborhood==j].index.values[0]
    for act in activities:
        df_weighted.loc[row,act] = df.loc[row,act]-df.loc[row_sim,act]
df_weighted['PjAreaCode'] = df['PjAreaCode']
df_weighted
# Out:
#                                          Neighborhood restaurants       bars  \
# 0                                     Upper West Side  -0.0688125   -0.14525
# 1                                     Stuyvesant Town    -0.41325   0.313375
# 2                      SoHo, TriBeCa and Little Italy   0.0688125    0.14525
# 3                                             Clinton   0.4473125     0.7265
# 4               Theater District and Garment District   0.8374375     0.6445
# 5                                         East Harlem    -0.35825  -0.257375
# 6                                  Washington Heights     -0.8895  -1.246875
# 7                                          Turtle Bay           0          0
# 8                                            Gramercy  -0.5890625   -0.51475
# 9                                     Upper East Side     0.18275    0.29225
# 10                                  Greenwich Village   0.4785625      0.219
# 11                                    Lower East Side   0.9083125   0.904125
# 12                                          Chinatown    0.377375     -0.333
# 13                                             Harlem   0.0246875     0.0915
# 14                                       East Village     0.45525   0.637375
# 15        Chelsea, Flatiron District and Union Square   0.4478125   0.863125
# 16                           Murray Hill and Kips Bay           0          0
# 17           Financial District and Battery Park City  -0.4785625     -0.219
# 18                                Morningside Heights    -0.08525      0.472
# 19                                       Clinton Hill  -0.0246875    -0.0915
# 20                                      Crown Heights     -0.2015  -0.349875
# 21                   Brooklyn Heights and Cobble Hill    -0.45525  -0.637375
# 22                             Park Slope and Gowanus   -0.377375      0.333
# 23                                           Bushwick      0.2015   0.349875
# 24                                       Williamsburg  -0.8374375    -0.6445
# 25                                        Fort Greene    -0.08025  -0.008125
# 26  Downtown Brooklyn, DUMBO, Vinegar Hill and Boe...     0.41325  -0.313375
# 27                                 Bedford-Stuyvesant  -0.9083125  -0.904125
# 28                                         Greenpoint     0.08025   0.008125
# 29                                  East Williamsburg       0.154   0.077875
# 30                       Carroll Gardens and Red Hook   0.1556875 -0.2217917
# 31                                   Prospect Heights  -0.4473125    -0.7265
#
#    coffee & tea health & medical arts & entertainment fitness & instruction  \
# 0      -0.10625          -0.1675              1.08125              -0.11375
# 1         0.445          -0.0775              0.78625                0.1625
# 2       0.10625           0.1675             -1.08125               0.11375
# 3       0.24375             0.61               0.7475               0.61625
# 4       0.29875          0.40875                 0.86                0.0675
# 5       -1.0225         -0.51625              -0.2325              -0.38875
# 6         -1.81         -0.74125           -0.7165789               -0.4225
# 7             0                0                    0                     0
# 8        0.0275          -0.1925              -0.7475               0.03125
# 9             0           0.5125              0.20625              -0.11375
# 10      0.68125          0.21875            0.2952632                0.5075
# 11      1.34375          0.57375               1.1125                0.7525
# 12        -0.34          0.42875              0.10375              -0.29375
# 13       0.1475          0.19875                 0.48               -0.1125
# 14         0.58           0.3425                  0.4              -0.12125
# 15        0.655             0.15              0.67875               0.88625
# 16            0                0                    0                     0
# 17     -0.68125         -0.21875           -0.2952632               -0.5075
# 18        0.145           -0.155            0.1301316                -0.195
# 19      -0.1475         -0.19875                -0.48                0.1125
# 20       -0.245           -0.375              0.06125              -0.24625
# 21        -0.58          -0.3425                 -0.4               0.12125
# 22         0.34         -0.42875             -0.10375               0.29375
# 23        0.245            0.375             -0.06125               0.24625
# 24     -0.29875         -0.40875                -0.86               -0.0675
# 25        0.145            0.055               0.0075                0.1075
# 26       -0.445           0.0775             -0.78625               -0.1625
# 27     -1.34375         -0.57375              -1.1125               -0.7525
# 28       -0.145           -0.055              -0.0075               -0.1075
# 29         0.24          0.04375              -0.3075               -0.0275
# 30   -0.5146429          0.61625           -0.2960526               -0.0925
# 31     -0.24375            -0.61              -0.7475              -0.61625
#
#       grocery education  haircut   boutique PjAreaCode
# 0    -0.68625     -0.18  0.16125    -0.8925       MN12
# 1       0.215     0.055  0.68125    0.07625       MN50
# 2     0.68625      0.18 -0.16125     0.8925       MN24
# 3   0.1332237   0.56375  0.84875     0.4575       MN15
# 4       0.055   0.03375  -0.2175    0.09125       MN17
# 5      -0.715   -0.7725  -1.0775  -0.465625       MN34
# 6    -1.24375  -0.44125 -2.11625     -0.955       MN35
# 7           0         0        0          0       MN19
# 8     0.57125    -0.255  0.05625       0.21       MN21
# 9     0.16125   0.03125     0.23   -0.31125       MN40
# 10    0.72375  -0.06375 -0.09125     0.9525       MN23
# 11       0.35   0.06625    0.835     0.4775       MN28
# 12     -0.065   0.09875 -1.00625    0.27125       MN27
# 13   -0.62375     -0.51  -0.3125 -0.1083333       MN11
# 14     0.0825    0.1825    0.985      0.855       MN22
# 15     1.1625    0.8225    1.085      0.255       MN13
# 16          0         0        0          0       MN20
# 17   -0.72375   0.06375  0.09125    -0.9525       MN25
# 18    0.35125  -0.02625  0.07125  0.1708333       MN09
# 19    0.62375      0.51   0.3125  0.1083333       BK69
# 20      -0.35  -0.14625     0.23 -0.1181818       BK61
# 21    -0.0825   -0.1825   -0.985     -0.855       BK09
# 22      0.065  -0.09875  1.00625   -0.27125       BK37
# 23       0.35   0.14625    -0.23  0.1181818       BK77
# 24     -0.055  -0.03375   0.2175   -0.09125       BK72
# 25    0.09125   -0.2075   0.3325    -0.3025       BK68
# 26     -0.215    -0.055 -0.68125   -0.07625       BK38
# 27      -0.35  -0.06625   -0.835    -0.4775       BK75
# 28   -0.09125    0.2075  -0.3325     0.3025       BK76
# 29    0.47625   0.63875  0.38125  0.1059524       BK90
# 30 -0.6166667    0.3475 -0.32125    0.10625       BK33
# 31 -0.1332237  -0.56375 -0.84875    -0.4575       BK64

# %%
rec_dict = {}
for i in df_weighted.index:
    nbhd = df_weighted.loc[i,'Neighborhood']
    loc_min = min(df_weighted.loc[i,activities].tolist())
    for act in activities:
        if df_weighted.loc[i,act]==loc_min:
            rec_dict[nbhd] = act
rec_dict
# Out:
# {'Bedford-Stuyvesant': 'coffee & tea',
#  'Brooklyn Heights and Cobble Hill': 'haircut',
#  'Bushwick': 'haircut',
#  'Carroll Gardens and Red Hook': 'grocery',
#  'Chelsea, Flatiron District and Union Square': 'health & medical',
#  'Chinatown': 'haircut',
#  'Clinton': 'grocery',
#  'Clinton Hill': 'arts & entertainment',
#  'Crown Heights': 'health & medical',
#  'Downtown Brooklyn, DUMBO, Vinegar Hill and Boerum Hill': 'arts & entertainment',
#  'East Harlem': 'haircut',
#  'East Village': 'fitness & instruction',
#  'East Williamsburg': 'arts & entertainment',
#  'Financial District and Battery Park City': 'boutique',
#  'Fort Greene': 'boutique',
#  'Gramercy': 'arts & entertainment',
#  'Greenpoint': 'haircut',
#  'Greenwich Village': 'haircut',
#  'Harlem': 'grocery',
#  'Lower East Side': 'education',
#  'Morningside Heights': 'fitness & instruction',
#  'Murray Hill and Kips Bay': 'boutique',
#  'Park Slope and Gowanus': 'health & medical',
#  'Prospect Heights': 'haircut',
#  'SoHo, TriBeCa and Little Italy': 'arts & entertainment',
#  'Stuyvesant Town': 'restaurants',
#  'Theater District and Garment District': 'haircut',
#  'Turtle Bay': 'boutique',
#  'Upper East Side': 'boutique',
#  'Upper West Side': 'boutique',
#  'Washington Heights': 'haircut',
#  'Williamsburg': 'arts & entertainment'}

# %%
df_nbhd = pd.DataFrame(columns=['PjAreaCode','Neighborhood'])
df_nbhd['PjAreaCode'] = df['PjAreaCode']
df_nbhd['Neighborhood'] = df['Neighborhood']
df_rec = pd.DataFrame(list(rec_dict.iteritems()),columns=['Neighborhood','RecBiz'])
df_out = pd.merge(df_nbhd, df_rec, on=['Neighborhood'])
df_out.to_csv('recbiz_mtxfact.csv')
