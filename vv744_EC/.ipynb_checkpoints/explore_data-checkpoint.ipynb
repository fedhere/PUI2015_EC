# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp

# %pylab inline

plt.style.use('bmh')
import sklearn.cluster as skc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ship_df = pd.read_csv('../../Data/Furman_Center_SHIP_Properties.csv')
edu_df = pd.read_csv('../../Data/Furman_Center_Neighborhood_Educational_Attainment.csv')
homeowner_df = pd.read_csv('../../Data/Furman_Center_Neighborhood_Info_homeowner.csv')
burdened_df = pd.read_csv('../../Data/Furman_Center_Neighborhood_Info_cost_burdened.csv')

cd = gp.read_file('../../Data/community-districts-polygon.geojson')

# %%
#Patterns with or without violence
with_violations = ship_df[ship_df['Serious Violations Issued in 2010'] != 0]
without_violations = ship_df[ship_df['Serious Violations Issued in 2010'] == 0]

# %% [markdown]
# ## Data Cleaning

# %%
ship_edu_df = pd.merge(ship_df, edu_df, left_on='CD', right_on='CommunityDistrict', how='inner')

# %%
ship_edu_time = ship_edu_df[['UID','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011']]

# %%
ship_edu_time = ship_edu_time.set_index('UID', drop = True)

# %%
ship_edu_time.head()
# Out:
#              1999       2000       2001       2002       2003       2004  \
# UID
# 100000  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100063  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100064  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100065  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100086  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
#
#              2005       2006       2007       2008       2009       2010  \
# UID
# 100000  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100063  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100064  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100065  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100086  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
#
#              2011
# UID
# 100000  46.036099
# 100063  46.036099
# 100064  46.036099
# 100065  46.036099
# 100086  46.036099

# %%
ship_edu_mat = ship_edu_time.as_matrix()

# %% [markdown]
# ## Data exploration

# %%
figure, ax = plt.subplots(figsize=(16,16))
ax.plot(ship_edu_mat.transpose())
ax.set_title('Educational Attainment by Community district')
ax.set_xticks(np.arange(13))
ax.set_xticklabels(1999 + np.arange(13))
ax.set_xlabel('Year')
ax.set_ylabel("Percentage with Bachelor's degree", fontsize = 20)
ax.legend()
figure.savefig('plot1.png')
# Out:
# /Library/Python/2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Normalizing data

# %%
temp = ship_edu_mat - (ship_edu_mat.sum(axis = 0))/(ship_edu_mat.shape[0])
norm_ship_edu_mat = temp/ship_edu_mat.std(axis = 0)

# %%
res = skc.KMeans(n_clusters=6).fit(norm_ship_edu_mat)

# %%
def plotClusters(clusters, labels):
    figure, ax = plt.subplots(figsize=(16,10))
    num_clusters = len(clusters)
    
    for i in range(num_clusters):
        ax.plot(norm_ship_edu_mat[labels == i].T)

    for i in range(num_clusters):
        ax.plot(clusters[i], label='Cluster %s' % i)

    ax.set_xlim([0,13])
    ax.set_title('Percent with Bachelore degree in NYC Clustered')
    ax.set_xticks(np.arange(13))
    ax.set_xticklabels(1999 + np.arange(13))
    ax.set_xlabel('Year')
    ax.set_ylabel('Normaized percent w/ bachelor degree')
    ax.legend()

# %%
plotClusters(res.cluster_centers_, res.labels_)

# %%
ship_edu_time = ship_edu_df[['UID','CD','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011']]

# %%
ship_edu_time['CD'][2311]
# Out:
# 'QN01: Astoria'

# %%
cd['communityDistrict'] = cd['communityDistrict'].astype(str)

# %%
def plotMap(labels):
    # Read in Zipcode geojson
    
    
    
    # Setup label data to be merged
    data['label'] = labels
    data['ZIP'] = data.index
    
    # Merge
    merged = zips.merge(data, left_on='postalCode', right_on='ZIP')
    
    # Plot
    figure, ax = pl.subplots(figsize=(16,16))
    merged.plot(axes=ax, column='label', legend=True, categorical=True)
    ax.set_title('Number of Business Establishments over 20 Years in NYC Clustered')

# %%
cd.head()
# Out:
#                                                  @id  communityDistrict  \
# 0  http://nyc.pediacities.com/Resource/CommunityD...                101
# 1  http://nyc.pediacities.com/Resource/CommunityD...                101
# 2  http://nyc.pediacities.com/Resource/CommunityD...                101
# 3  http://nyc.pediacities.com/Resource/CommunityD...                101
# 4  http://nyc.pediacities.com/Resource/CommunityD...                106
#
#                                             geometry
# 0  POLYGON ((-74.01115034338935 40.72577721688008...
# 1  POLYGON ((-74.0167475609607 40.69334336821758,...
# 2  POLYGON ((-74.03995040788513 40.7008906306427,...
# 3  POLYGON ((-74.04387761639912 40.69018767537122...
# 4  POLYGON ((-73.97446922636118 40.73579461792766...

# %%
ship_edu_time.head()
# Out:
#              1999       2000       2001       2002       2003       2004  \
# UID
# 100000  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100063  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100064  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100065  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
# 100086  24.587999  24.074655  24.331679  27.259724  32.991513  37.704054
#
#              2005       2006       2007       2008       2009       2010  \
# UID
# 100000  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100063  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100064  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100065  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
# 100086  44.094062  47.775221  55.311595  66.209458  74.911028  43.660697
#
#              2011
# UID
# 100000  46.036099
# 100063  46.036099
# 100064  46.036099
# 100065  46.036099
# 100086  46.036099

# %%
'MN','BX','BK','QN','ST'
