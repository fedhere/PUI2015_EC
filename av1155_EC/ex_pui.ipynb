# %%
import pandas as pd
import os
import json
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd desktop/NYU/courses/PUI2015
# Out:
# [Errno 2] No such file or directory: 'desktop/NYU/courses/PUI2015'
# /Users/yiftah/Dropbox/NYU/courses/PUI2015

# %%
dataset = pd.read_csv("ESTIMATES-Table 1.csv")
dataset.head()
# Out:
#                                              country  1950  1955  1960  1965  \
# 0                                              WORLD  56.7  59.9  64.1  66.5
# 1                             More developed regions  42.3  42.5  44.7  43.1
# 2                             Less developed regions  64.3  68.9  73.7  77.7
# 3                          Least developed countries  74.3  75.8  78.2  81.3
# 4  Less developed regions, excluding least develo...  63.1  68.0  73.2  77.2
#
#    1970  1975  1980  1985  1990  1995  2000  2005  2010  2015
# 0  65.8  64.2  60.3  56.2  53.9  51.7  47.9  43.4  40.6  39.7
# 1  40.4  37.1  34.2  32.0  30.6  29.3  27.0  25.0  24.3  24.8
# 2  77.1  75.3  70.1  64.5  61.1  58.0  53.3  47.8  44.3  42.8
# 3  83.7  85.1  85.9  86.2  85.6  83.1  80.3  77.6  74.9  70.8
# 4  76.3  74.1  68.1  61.9  58.1  54.9  49.8  43.7  39.9  38.4

# %%
dataset.columns
# Out:
# Index([u'country', u'1950', u'1955', u'1960', u'1965', u'1970', u'1975',
#        u'1980', u'1985', u'1990', u'1995', u'2000', u'2005', u'2010', u'2015'],
#       dtype='object')

# %%
dataset.plot(figsize=(12,8));

# %%
dataset= dataset.rename(columns={'1950' : 'y1950','1955' : 'y1955', '1960' : 'y1960', '1965' : 'y1965', '1970' : 'y1970', '1975' : 'y1975','1980' : 'y1980','1985' : 'y1985', '1990' : 'y1990','1995' : 'y1995', '2000' : 'y2000', '2005' : 'y2005', '2010' : 'y2010', '2015' : 'y2015'})
dataset.head(10)
# Out:
#                                              country  y1950  y1955  y1960  \
# 0                                              WORLD   56.7   59.9   64.1
# 1                             More developed regions   42.3   42.5   44.7
# 2                             Less developed regions   64.3   68.9   73.7
# 3                          Least developed countries   74.3   75.8   78.2
# 4  Less developed regions, excluding least develo...   63.1   68.0   73.2
# 5            Less developed regions, excluding China   68.4   70.7   75.0
# 6                              High-income countries   44.0   44.6   46.8
# 7                            Middle-income countries   62.1   66.8   72.0
# 8                      Upper-middle-income countries   59.7   66.8   72.5
# 9                      Lower-middle-income countries   64.8   66.8   71.4
#
#    y1965  y1970  y1975  y1980  y1985  y1990  y1995  y2000  y2005  y2010  y2015
# 0   66.5   65.8   64.2   60.3   56.2   53.9   51.7   47.9   43.4   40.6   39.7
# 1   43.1   40.4   37.1   34.2   32.0   30.6   29.3   27.0   25.0   24.3   24.8
# 2   77.7   77.1   75.3   70.1   64.5   61.1   58.0   53.3   47.8   44.3   42.8
# 3   81.3   83.7   85.1   85.9   86.2   85.6   83.1   80.3   77.6   74.9   70.8
# 4   77.2   76.3   74.1   68.1   61.9   58.1   54.9   49.8   43.7   39.9   38.4
# 5   79.1   79.0   77.0   74.3   72.0   69.1   65.1   60.2   55.8   52.2   49.5
# 6   45.6   43.3   39.8   36.5   34.2   32.7   31.3   29.1   27.0   25.9   26.0
# 7   76.0   75.3   73.6   68.3   62.4   59.0   55.7   50.7   44.7   41.0   39.5
# 8   76.3   74.7   72.8   64.4   54.8   50.2   47.1   41.6   33.9   30.0   29.5
# 9   75.8   75.9   74.4   72.5   70.9   68.6   65.0   59.8   55.4   51.6   48.7

# %%
import matplotlib.pyplot as pl
x = np.array([dataset.y1950,dataset.y1955,dataset.y1960,dataset.y1965, \
dataset.y1970,dataset.y1975,dataset.y1980,dataset.y1985,dataset.y1990,dataset.y1995, dataset.y2000,dataset.y2005, dataset.y2010,dataset.y2015])
print x.T.shape
plt.figure()
plt.legend(loc=1)
pl.plot(x)

pl.ylabel('old depndeny ratio',fontsize=20)
pl.xlabel('years', fontsize=20)
figsize(30,10)

plt.show()
# Out:
# (241, 14)
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
x.transpose()
# Out:
# array([[  56.7,   59.9,   64.1, ...,   43.4,   40.6,   39.7],
#        [  42.3,   42.5,   44.7, ...,   25. ,   24.3,   24.8],
#        [  64.3,   68.9,   73.7, ...,   47.8,   44.3,   42.8],
#        ...,
#        [  74.1,   77.4,   79.8, ...,   41.3,   34.2,   31.5],
#        [  92.2,   99.3,  102.3, ...,   71.2,   67.5,   64.9],
#        [  99. ,   86.7,   88.7, ...,   68. ,   66. ,   64.1]])

# %%
dictio = {}
for i in range(len(dataset.index)):
    dictio[dataset.country[i]] = x.transpose()[i]

# %%
x
# Out:
# array([[  56.7,   42.3,   64.3, ...,   74.1,   92.2,   99. ],
#        [  59.9,   42.5,   68.9, ...,   77.4,   99.3,   86.7],
#        [  64.1,   44.7,   73.7, ...,   79.8,  102.3,   88.7],
#        ...,
#        [  43.4,   25. ,   47.8, ...,   41.3,   71.2,   68. ],
#        [  40.6,   24.3,   44.3, ...,   34.2,   67.5,   66. ],
#        [  39.7,   24.8,   42.8, ...,   31.5,   64.9,   64.1]])

# %%
x.shape
# Out:
# (14, 241)

# %%
figsize(15,5)
plot(x)
pl.xlabel('time', fontsize=25)
pl.ylabel('ratio', fontsize=25)
pl.title('First attempt: countries along time', fontsize=30)
pl.show()

# %%
#add dicionary for countries and years

# %%
#finding outliers for 
print dataset['y1950'][:10],  dataset['y1950'].shape
print dataset['y1950'].mean(), dataset['y1950'].std()
thresholds = [dataset['y1950'].mean() + 2*dataset['y1950'].std(), 
              dataset['y1950'].mean() - 2*dataset['y1950'].std()]
thresholds15 = [dataset['y2015'].mean() + 2*dataset['y2015'].std(), 
              dataset['y2015'].mean() - 2*dataset['y2015'].std()]
print thresholds
print thresholds15
print min(dataset.index)
# Out:
# 0    56.7
# 1    42.3
# 2    64.3
# 3    74.3
# 4    63.1
# 5    68.4
# 6    44.0
# 7    62.1
# 8    59.7
# 9    64.8
# Name: y1950, dtype: float64 (241,)
# 64.3917012448 16.255617414
# [96.902936072815322, 31.880466416811259]
# [89.175546761401975, 2.0991420352785326]
# 0

# %%
#ploting 1950 to 2015 to find stationarity 
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [thresholds[0], thresholds[0]], color="Blue")
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [thresholds[1], thresholds[1]],color="Blue")
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [thresholds15[0], thresholds15[0]],color="Red")
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [thresholds15[1], thresholds15[1]],color="Red")
ax=dataset['y1950'].plot(logy= False, color="Red")
ax=dataset['y2015'].plot(logy= False, color="Blue")
pl.xlabel('Contry', fontsize=30)
pl.ylabel('Ratio', fontsize=30)
pl.title('1950 to 2015', fontsize=50)

# %%
 mean50= dataset['y1950'].mean()

# %%
#ploting the data for each year sorted
pl.legend()

sortindex = dataset['y1950'].argsort()
pl.plot(dataset['y1950'][sortindex], color= 'Yellow', alpha=0.3,linewidth=3.0)

sortindex = dataset['y1955'].argsort()
pl.plot(dataset['y1955'][sortindex], color= 'Yellow', alpha= 0.5,linewidth=3.0)

sortindex = dataset['y1960'].argsort()
pl.plot(dataset['y1960'][sortindex], color= 'Yellow', alpha=0.7,linewidth=3.0)

sortindex = dataset['y1965'].argsort()
pl.plot(dataset['y1965'][sortindex], color= 'Yellow', alpha=0.9,linewidth=3.0)

sortindex = dataset['y1980'].argsort()
pl.plot(dataset['y1980'][sortindex], color= 'Orange', alpha=0.3,linewidth=3.0)

sortindex = dataset['y1985'].argsort()
pl.plot(dataset['y1985'][sortindex], color= 'Orange', alpha=0.5,linewidth=3.0)

sortindex = dataset['y1990'].argsort()
pl.plot(dataset['y1990'][sortindex], color= 'Orange', alpha=0.7,linewidth=3.0)

sortindex = dataset['y1995'].argsort()
pl.plot(dataset['y1995'][sortindex], color= 'Orange', alpha=0.9,linewidth=3.0)


sortindex = dataset['y2000'].argsort()
pl.plot(dataset['y2000'][sortindex], color= 'Red', alpha=0.3,linewidth=3.0)

sortindex = dataset['y2005'].argsort()
pl.plot(dataset['y2005'][sortindex], color= 'Red', alpha=0.3,linewidth=3.0)

sortindex = dataset['y2010'].argsort()
pl.plot(dataset['y2010'][sortindex], color= 'Red', alpha=0.5,linewidth=3.0)

sortindex = dataset['y2015'].argsort()
pl.plot(dataset['y2015'][sortindex], color= 'Red', alpha=0.7,linewidth=3.0)


pl.title('')
xlabel("Country", fontsize=35)
ylabel("Old Depndency Ratio", fontsize=35)
pl.show()


print dataset['country'][sortindex].values[:10]
print dataset['country'][sortindex].values[-10:]
print dataset['y1980'][sortindex].values[-10:]
#ginindex [sortindex]
# Out:
# ['United Arab Emirates' 'China, Hong Kong SAR' 'China, Macao SAR'
#  'Other non-specified areas' 'Qatar' 'Bosnia and Herzegovina'
#  'Republic of Korea' 'Germany' 'Japan' 'Austria']
# ['Mozambique' 'Zambia' 'Gambia' 'Democratic Republic of the Congo'
#  'Somalia' 'Mali' 'Angola' 'Chad' 'Uganda' 'Niger']
# [ 83.1  97.9  86.7  84.9  82.5  83.6  93.1  87.6  94.9  93.9]

# %%
# Changes throught time
figsize=(20,20)
pl.legend()
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
pl.legend()

#sortindex = dataset['y1950'].argsort()
pl.plot(dataset['y1950'], color= 'Yellow', alpha=0.3,linewidth=3.0)

#sortindex = dataset['y1955'].argsort()
pl.plot(dataset['y1955'], color= 'Yellow', alpha= 0.5,linewidth=3.0)

#sortindex = dataset['y1960'].argsort()
pl.plot(dataset['y1960'], color= 'Yellow', alpha=0.7,linewidth=3.0)

#sortindex = dataset['y1965'].argsort()
pl.plot(dataset['y1965'], color= 'Yellow', alpha=0.9,linewidth=3.0)

#sortindex = dataset['y1980'].argsort()
pl.plot(dataset['y1980'][sortindex], color= 'Orange', alpha=0.3,linewidth=3.0)

#sortindex = dataset['y1985'].argsort()
pl.plot(dataset['y1985'][sortindex], color= 'Orange', alpha=0.5,linewidth=3.0)

#sortindex = dataset['y1990'].argsort()
pl.plot(dataset['y1990'][sortindex], color= 'Orange', alpha=0.7,linewidth=3.0)

#sortindex = dataset['y1995'].argsort()
pl.plot(dataset['y1995'], color= 'Orange', alpha=0.9,linewidth=3.0)

#sortindex = dataset['y2000'].argsort()
pl.plot(dataset['y2000'], color= 'Red', alpha=0.3,linewidth=3.0)

#sortindex = dataset['y2005'].argsort()
pl.plot(dataset['y2005'], color= 'Red', alpha=0.3,linewidth=3.0)

#sortindex = dataset['y2010'].argsort()
pl.plot(dataset['y2010'], color= 'Red', alpha=0.5,linewidth=3.0)

#sortindex = dataset['y2015'].argsort()
pl.plot(dataset['y2015'], color= 'Red', alpha=0.7,linewidth=3.0)


b= [dataset['y1950'].mean(), 
    dataset['y2015'].mean()]
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [b[0], b[0]],color="Red")
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [b[1], b[1]],color="Black")

pl.title('Child Depndency Ratio across time: Yellow to Red', fontsize=30)


xlabel("Country", fontsize=25)
ylabel("Ratio", fontsize=25)

pl.show()

# %%
print '1950 bottom 10',dataset['country'][sortindex50].values[-10:]
print '1955 bottom 10',dataset['country'][sortindex55].values[-10:]
print '1960 bottom 10',dataset['country'][sortindex60].values[-10:]
print '1965 bottom 10',dataset['country'][sortindex65].values[-10:]
print '1970 bottom 10',dataset['country'][sortindex70].values[-10:]
print '1975 bottom 10',dataset['country'][sortindex75].values[-10:]
print '1980 bottom 10',dataset['country'][sortindex80].values[-10:]
print '1985 bottom 10',dataset['country'][sortindex85].values[-10:]
print '1990 bottom 10',dataset['country'][sortindex90].values[-10:]
print '1995 bottom 10',dataset['country'][sortindex95].values[-10:]
print '2000 bottom 10',dataset['country'][sortindex00].values[-10:]
print '2005 bottom 10',dataset['country'][sortindex05].values[-10:]
print '2010 bottom 10',dataset['country'][sortindex10].values[-10:]
print '2015 bottom 10',dataset['country'][sortindex15].values[-10:]
# Out:
# 1950 bottom 10 ['Djibouti' 'State of Palestine' 'Samoa' 'Jordan' 'Fiji' 'Paraguay' 'Tonga'
#  'Niger' 'Grenada' 'Saint Vincent and the Grenadines']
# 1955 bottom 10 ['Philippines' 'Vanuatu' 'Dominican Republic' 'State of Palestine'
#  'Grenada' 'Paraguay' 'Niger' 'Fiji' 'Samoa'
#  'Saint Vincent and the Grenadines']
# 1960 bottom 10 ['Nicaragua' 'Niger' 'Rwanda' 'Fiji' 'Dominican Republic' 'Paraguay'
#  'Suriname' 'Samoa' 'Grenada' 'Saint Vincent and the Grenadines']
# 1965 bottom 10 ['Botswana' 'Syrian Arab Republic' 'Kenya' 'Suriname' 'Dominican Republic'
#  'Nicaragua' 'Rwanda' 'Grenada' 'Samoa' 'Saint Vincent and the Grenadines']
# 1970 bottom 10 ['Polynesia' 'Jamaica' 'Suriname' 'Cabo Verde' 'Kenya' 'State of Palestine'
#  'Grenada' 'Samoa' 'Saint Vincent and the Grenadines' 'Saint Lucia']
# 1975 bottom 10 ['Micronesia (Fed. States of)' 'Syrian Arab Republic' 'Belize' 'Zimbabwe'
#  'Saint Vincent and the Grenadines' 'Cabo Verde' 'Samoa' 'Mayotte' 'Kenya'
#  'State of Palestine']
# 1980 bottom 10 ['Sao Tome and Principe' 'Cabo Verde' 'Swaziland' 'Syrian Arab Republic'
#  'Zimbabwe' 'Jordan' 'Yemen' 'State of Palestine' 'Mayotte' 'Kenya']
# 1985 bottom 10 ['Solomon Islands' 'Zimbabwe' 'Syrian Arab Republic'
#  'Sao Tome and Principe' 'State of Palestine' 'Swaziland' 'Mayotte'
#  'Rwanda' 'Kenya' 'Yemen']
# 1990 bottom 10 ['Afghanistan' 'Burundi' 'Uganda' 'Swaziland' 'Mayotte'
#  'State of Palestine' 'Sao Tome and Principe' 'Kenya' 'Rwanda' 'Yemen']
# 1995 bottom 10 ['Niger' 'Afghanistan' 'Angola' 'Swaziland' 'State of Palestine' 'Chad'
#  'Uganda' 'Eritrea' 'Burundi' 'Yemen']
# 2000 bottom 10 ['Somalia' 'State of Palestine' 'Angola' 'Niger' 'Afghanistan' 'Yemen'
#  'Burundi' 'Chad' 'Uganda' 'Timor-Leste']
# 2005 bottom 10 ['Zambia' 'Democratic Republic of the Congo' 'Malawi' 'Afghanistan'
#  'Somalia' 'Angola' 'Timor-Leste' 'Niger' 'Chad' 'Uganda']
# 2010 bottom 10 ['Malawi' 'Democratic Republic of the Congo' 'Zambia' 'Mali' 'Afghanistan'
#  'Somalia' 'Angola' 'Chad' 'Uganda' 'Niger']
# 2015 bottom 10 ['Mozambique' 'Zambia' 'Gambia' 'Democratic Republic of the Congo'
#  'Somalia' 'Mali' 'Angola' 'Chad' 'Uganda' 'Niger']

# %%
sortindex = dataset['y1950'].argsort()
pl.plot(dataset['y1950'][sortindex])
print dataset['country'][sortindex].values[:10]
print dataset['country'][sortindex].values[-10:]
print dataset['y1950'][sortindex].values[-10:]
# Out:
# ['Luxembourg' 'Belgium' 'Channel Islands' 'United Kingdom' 'Austria'
#  'France' 'Germany' 'Sweden' 'Western Europe' 'Switzerland']
# ['Djibouti' 'State of Palestine' 'Samoa' 'Jordan' 'Fiji' 'Paraguay' 'Tonga'
#  'Niger' 'Grenada' 'Saint Vincent and the Grenadines']
# [  91.4   91.4   92.2   92.4   92.5   93.8   99.    99.7  101.1  105.5]

# %%
dataset.loc[(dataset.y1950>64.3917012448)]
# Out:
#                                      country  y1950  y1955  y1960  y1965  \
# 3                  Least developed countries   74.3   75.8   78.2   81.3
# 5    Less developed regions, excluding China   68.4   70.7   75.0   79.1
# 9              Lower-middle-income countries   64.8   66.8   71.4   75.8
# 10                      Low-income countries   76.6   77.0   78.2   80.1
# 11                        Sub-Saharan Africa   76.0   77.3   79.0   81.3
# 12                                    AFRICA   74.6   76.6   79.5   82.3
# 13                            Eastern Africa   79.6   81.7   84.1   86.5
# 14                                   Burundi   73.2   77.4   81.4   86.5
# 15                                   Comoros   64.8   68.8   75.8   84.5
# 16                                  Djibouti   91.4   83.7   79.8   79.7
# 17                                   Eritrea   87.7   87.2   85.9   82.7
# 18                                  Ethiopia   83.3   82.2   80.6   80.4
# 19                                     Kenya   70.6   80.3   93.1  100.8
# 20                                Madagascar   65.2   70.9   79.0   86.7
# 21                                    Malawi   89.2   87.2   85.0   83.6
# 22                                 Mauritius   87.0   89.8   91.5   91.2
# 24                                Mozambique   75.1   75.6   76.9   79.0
# 25                                   Réunion   70.3   82.3   87.2   89.6
# 26                                    Rwanda   80.0   87.8   97.0  103.0
# 28                                   Somalia   73.4   75.1   78.2   79.8
# 29                               South Sudan   82.6   77.2   74.5   75.1
# 30                                    Uganda   79.8   86.5   89.1   91.6
# 31               United Republic of Tanzania   88.7   88.0   88.4   88.6
# 32                                    Zambia   85.8   86.1   87.5   89.9
# 33                                  Zimbabwe   76.6   82.8   88.1   97.5
# 34                             Middle Africa   74.8   75.9   77.3   79.5
# 35                                    Angola   73.9   78.5   83.5   89.1
# 36                                  Cameroon   69.7   70.0   71.0   73.7
# 38                                      Chad   65.4   69.9   74.1   78.8
# 39                                     Congo   71.1   72.5   75.2   79.1
# ..                                       ...    ...    ...    ...    ...
# 197                          Central America   79.1   85.4   90.1   93.5
# 198                                   Belize   66.7   82.2   89.5   96.8
# 199                               Costa Rica   81.5   82.6   85.6   85.1
# 200                              El Salvador   80.1   82.2   86.7   90.0
# 201                                Guatemala   84.3   87.4   88.8   86.9
# 202                                 Honduras   78.5   84.6   90.8   94.7
# 203                                   Mexico   78.5   85.6   90.6   94.7
# 204                                Nicaragua   79.4   86.7   94.5  101.6
# 205                                   Panama   78.1   80.9   83.5   85.3
# 206                            South America   69.7   72.6   76.3   78.2
# 208         Bolivia (Plurinational State of)   72.7   78.3   79.7   81.2
# 209                                   Brazil   74.9   76.9   81.0   82.8
# 211                                 Colombia   79.1   86.1   92.2   94.0
# 212                                  Ecuador   72.4   79.0   83.6   87.8
# 214                                   Guyana   71.2   82.3   91.3   97.5
# 215                                 Paraguay   93.8   96.3   98.0   96.9
# 216                                     Peru   75.6   78.5   82.5   85.7
# 217                                 Suriname   74.1   83.2   98.6  101.0
# 219       Venezuela (Bolivarian Republic of)   87.2   86.1   88.3   91.8
# 227                                Melanesia   72.7   76.6   79.4   80.9
# 228                                     Fiji   92.5   96.5   97.6   92.1
# 230                         Papua New Guinea   69.6   73.5   76.6   79.1
# 231                          Solomon Islands   76.7   77.6   77.8   81.5
# 232                                  Vanuatu   90.7   90.4   90.0   89.8
# 235                                 Kiribati   73.3   78.2   88.4   91.9
# 236              Micronesia (Fed. States of)   72.8   81.9   88.8   95.4
# 237                                Polynesia   86.8   88.3   92.3   99.1
# 238                         French Polynesia   74.1   77.4   79.8   89.6
# 239                                    Samoa   92.2   99.3  102.3  111.0
# 240                                    Tonga   99.0   86.7   88.7   91.4
#
#      y1970  y1975  y1980  y1985  y1990  y1995  y2000  y2005  y2010  y2015
# 3     83.7   85.1   85.9   86.2   85.6   83.1   80.3   77.6   74.9   70.8
# 5     79.0   77.0   74.3   72.0   69.1   65.1   60.2   55.8   52.2   49.5
# 9     75.9   74.4   72.5   70.9   68.6   65.0   59.8   55.4   51.6   48.7
# 10    82.7   83.8   84.3   85.2   86.0   86.1   85.6   84.3   82.3   78.5
# 11    83.2   85.2   86.7   88.2   88.1   85.8   84.5   83.2   82.1   79.8
# 12    83.9   84.9   85.4   86.1   85.4   82.2   79.1   76.4   74.9   73.8
# 13    88.5   90.3   91.3   92.5   92.5   90.4   89.3   87.5   85.3   81.3
# 14    87.7   88.0   84.7   89.9   97.2  103.0  101.1   87.4   82.3   85.0
# 15    87.0   87.0   88.2   91.0   92.3   89.1   83.0   77.2   73.5   70.7
# 16    87.0   92.7   90.8   85.1   85.2   80.1   74.7   63.6   55.1   51.9
# 17    84.7   86.2   88.0   89.5   91.3  102.0   89.0   75.1   76.5   78.4
# 18    82.5   85.7   87.2   90.7   91.6   92.7   92.2   91.0   85.0   75.2
# 19   103.3  105.4  106.3  105.9  101.3   91.3   83.8   79.0   77.9   75.8
# 20    88.9   91.3   92.1   88.8   87.1   85.9   88.3   85.8   80.8   75.2
# 21    87.9   91.3   93.8   95.2   88.8   91.6   93.6   92.7   91.3   87.9
# 22    81.6   68.9   58.6   50.1   43.7   40.8   37.8   36.0   31.2   27.2
# 24    81.0   82.3   83.1   87.0   95.8   86.1   86.5   88.9   90.3   88.2
# 25    88.4   77.3   64.8   54.1   48.7   46.2   44.2   40.8   38.5   35.7
# 26    96.7   93.9   96.7  102.8  103.6   81.1   87.0   76.8   77.4   73.1
# 28    80.9   81.8   82.5   83.7   86.4   89.8   94.5   96.6   96.4   92.5
# 29    80.6   83.3   84.2   82.9   83.4   84.5   86.0   84.3   81.4   77.3
# 30    92.7   94.0   94.9   95.6   97.5  100.7  102.7  102.9  101.0   97.3
# 31    90.2   91.1   91.6   91.1   89.7   87.9   86.1   86.7   87.0   87.6
# 32    94.0   96.5   97.9   95.7   95.1   93.5   91.7   92.3   92.4   89.7
# 33    98.8   99.8  101.7   97.6   90.5   85.0   79.0   76.4   75.2   75.0
# 34    81.6   84.2   86.3   88.3   90.4   91.6   91.4   91.1   90.0   87.9
# 35    89.7   91.0   93.1   95.2   96.3   95.9   96.1   97.0   97.3   95.2
# 36    77.9   82.7   86.5   90.2   92.2   91.7   88.2   84.6   81.4   78.4
# 38    79.7   82.8   87.6   92.6   96.2   99.1  101.1  101.7   99.8   95.8
# 39    82.7   85.3   87.6   86.4   83.0   78.7   76.2   77.2   77.5   79.4
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 197   92.3   91.6   87.8   80.9   71.2   64.4   59.6   54.8   49.1   43.9
# 198   97.0   99.7   95.1   87.7   82.9   80.8   73.6   67.5   59.0   50.9
# 199   82.5   71.8   62.6   58.5   58.4   54.8   48.4   41.4   36.2   32.4
# 200   89.2   86.1   82.9   78.7   71.6   65.3   61.8   56.8   49.1   41.7
# 201   85.0   85.8   88.1   90.1   88.5   85.3   80.9   76.3   69.3   62.6
# 202   97.0   96.3   94.3   91.3   88.9   85.0   79.2   70.6   60.0   50.1
# 203   93.5   93.3   88.9   80.4   68.6   61.1   56.5   52.1   46.7   41.9
# 204   97.1   93.2   93.2   93.6   89.6   80.9   70.1   60.2   52.5   46.3
# 205   84.5   80.8   74.4   67.2   60.4   54.8   51.1   47.4   44.6   41.7
# 206   75.6   70.9   66.1   62.5   58.9   53.6   48.3   43.9   39.9   36.5
# 208   79.2   78.5   78.6   78.0   76.0   72.1   67.7   63.2   58.4   53.1
# 209   78.6   72.4   66.2   62.8   58.4   51.7   45.5   41.3   37.4   33.3
# 211   90.7   82.1   72.9   65.2   61.1   56.0   49.5   43.9   39.0   35.4
# 212   85.8   82.4   77.5   71.6   66.4   61.9   57.6   52.9   48.7   45.1
# 214   94.5   86.6   80.9   69.7   57.8   58.1   59.7   62.9   54.7   43.5
# 215   91.5   84.4   79.2   76.1   75.5   72.6   66.7   58.9   52.8   47.2
# 216   85.1   82.3   78.2   72.1   67.0   61.3   56.5   50.6   45.6   42.7
# 217  100.8   97.5   70.6   58.6   55.4   56.8   55.1   46.2   43.8   40.4
# 219   90.6   83.0   73.5   67.4   64.9   60.7   55.5   49.9   45.8   42.8
# 227   80.0   82.2   82.7   81.1   74.6   70.1   68.1   66.0   63.6   59.7
# 228   81.1   70.0   67.5   67.2   65.6   60.5   56.9   46.7   43.8   43.9
# 230   80.2   84.8   86.1   84.0   76.2   71.8   70.1   69.3   66.9   62.1
# 231   81.2   96.0   95.8   96.1   87.8   80.2   75.9   74.1   72.7   69.1
# 232   87.5   86.3   84.8   84.6   83.4   79.4   75.2   69.5   66.0   61.6
# 235   86.6   75.1   68.9   68.6   71.6   74.2   70.5   62.0   59.7   57.0
# 236   90.6   98.2   96.3   89.6   84.3   82.3   72.0   67.8   62.3   55.3
# 237   99.1   90.4   78.3   68.8   65.5   64.6   61.2   55.6   49.9   46.7
# 238   88.6   79.3   70.3   59.8   58.3   55.2   49.6   41.3   34.2   31.5
# 239  108.9  104.9   90.6   79.2   72.4   73.8   74.3   71.2   67.5   64.9
# 240   98.2   88.8   75.8   73.7   70.2   71.7   68.5   68.0   66.0   64.1
#
# [138 rows x 15 columns]

# %%
dataset.loc[(dataset.y1950<thresholds[1])]
# Out:
# Empty DataFrame
# Columns: [country, y1950, y1955, y1960, y1965, y1970, y1975, y1980, y1985, y1990, y1995, y2000, y2005, y2010, y2015]
# Index: []

# %%
countries = df.as_matrix(columns=['y1950'])

# %%
import sklearn.cluster
from sklearn import mixture
from PIL import Image
from scipy.misc import imread
from scipy.cluster.vq import kmeans2
import json
import os

# %%
dataset.y1950.min()
# Out:
# 28.399999999999999

# %%
dataset.y2015.max()
# Out:
# 107.5

# %%
dataset.y2015.min()
# Out:
# 16.399999999999999

# %%
#dataset.country
e= dataset[1:2]
print e
# Out:
#                   country  y1950  y1955  y1960  y1965  y1970  y1975  y1980  \
# 1  More developed regions   42.3   42.5   44.7   43.1   40.4   37.1   34.2
#
#    y1985  y1990  y1995  y2000  y2005  y2010  y2015
# 1     32   30.6   29.3     27     25   24.3   24.8

# %%
datasetT = dataset.transpose()
datasetT
# Out:
#            0                       1                       2    \
# country  WORLD  More developed regions  Less developed regions
# y1950     56.7                    42.3                    64.3
# y1955     59.9                    42.5                    68.9
# y1960     64.1                    44.7                    73.7
# y1965     66.5                    43.1                    77.7
# y1970     65.8                    40.4                    77.1
# y1975     64.2                    37.1                    75.3
# y1980     60.3                    34.2                    70.1
# y1985     56.2                      32                    64.5
# y1990     53.9                    30.6                    61.1
# y1995     51.7                    29.3                      58
# y2000     47.9                      27                    53.3
# y2005     43.4                      25                    47.8
# y2010     40.6                    24.3                    44.3
# y2015     39.7                    24.8                    42.8
#
#                                3    \
# country  Least developed countries
# y1950                         74.3
# y1955                         75.8
# y1960                         78.2
# y1965                         81.3
# y1970                         83.7
# y1975                         85.1
# y1980                         85.9
# y1985                         86.2
# y1990                         85.6
# y1995                         83.1
# y2000                         80.3
# y2005                         77.6
# y2010                         74.9
# y2015                         70.8
#
#                                                        4    \
# country  Less developed regions, excluding least develo...
# y1950                                                 63.1
# y1955                                                   68
# y1960                                                 73.2
# y1965                                                 77.2
# y1970                                                 76.3
# y1975                                                 74.1
# y1980                                                 68.1
# y1985                                                 61.9
# y1990                                                 58.1
# y1995                                                 54.9
# y2000                                                 49.8
# y2005                                                 43.7
# y2010                                                 39.9
# y2015                                                 38.4
#
#                                              5                      6    \
# country  Less developed regions, excluding China  High-income countries
# y1950                                       68.4                     44
# y1955                                       70.7                   44.6
# y1960                                         75                   46.8
# y1965                                       79.1                   45.6
# y1970                                         79                   43.3
# y1975                                         77                   39.8
# y1980                                       74.3                   36.5
# y1985                                         72                   34.2
# y1990                                       69.1                   32.7
# y1995                                       65.1                   31.3
# y2000                                       60.2                   29.1
# y2005                                       55.8                     27
# y2010                                       52.2                   25.9
# y2015                                       49.5                     26
#
#                              7                              8    \
# country  Middle-income countries  Upper-middle-income countries
# y1950                       62.1                           59.7
# y1955                       66.8                           66.8
# y1960                         72                           72.5
# y1965                         76                           76.3
# y1970                       75.3                           74.7
# y1975                       73.6                           72.8
# y1980                       68.3                           64.4
# y1985                       62.4                           54.8
# y1990                         59                           50.2
# y1995                       55.7                           47.1
# y2000                       50.7                           41.6
# y2005                       44.7                           33.9
# y2010                         41                             30
# y2015                       39.5                           29.5
#
#                                    9    ...                231      232  \
# country  Lower-middle-income countries  ...    Solomon Islands  Vanuatu
# y1950                             64.8  ...               76.7     90.7
# y1955                             66.8  ...               77.6     90.4
# y1960                             71.4  ...               77.8       90
# y1965                             75.8  ...               81.5     89.8
# y1970                             75.9  ...               81.2     87.5
# y1975                             74.4  ...                 96     86.3
# y1980                             72.5  ...               95.8     84.8
# y1985                             70.9  ...               96.1     84.6
# y1990                             68.6  ...               87.8     83.4
# y1995                               65  ...               80.2     79.4
# y2000                             59.8  ...               75.9     75.2
# y2005                             55.4  ...               74.1     69.5
# y2010                             51.6  ...               72.7       66
# y2015                             48.7  ...               69.1     61.6
#
#                 233   234       235                          236        237  \
# country  Micronesia  Guam  Kiribati  Micronesia (Fed. States of)  Polynesia
# y1950          59.4  37.9      73.3                         72.8       86.8
# y1955          69.5  51.9      78.2                         81.9       88.3
# y1960          80.4  68.6      88.4                         88.8       92.3
# y1965          82.3  66.7      91.9                         95.4       99.1
# y1970            80  65.8      86.6                         90.6       99.1
# y1975          75.9  60.2      75.1                         98.2       90.4
# y1980          72.4  54.8      68.9                         96.3       78.3
# y1985          66.4  49.8      68.6                         89.6       68.8
# y1990          61.5  45.1      71.6                         84.3       65.5
# y1995          60.5    48      74.2                         82.3       64.6
# y2000          54.2  47.5      70.5                           72       61.2
# y2005          51.3    46        62                         67.8       55.6
# y2010          49.5  42.2      59.7                         62.3       49.9
# y2015            46  38.7        57                         55.3       46.7
#
#                       238    239    240
# country  French Polynesia  Samoa  Tonga
# y1950                74.1   92.2     99
# y1955                77.4   99.3   86.7
# y1960                79.8  102.3   88.7
# y1965                89.6    111   91.4
# y1970                88.6  108.9   98.2
# y1975                79.3  104.9   88.8
# y1980                70.3   90.6   75.8
# y1985                59.8   79.2   73.7
# y1990                58.3   72.4   70.2
# y1995                55.2   73.8   71.7
# y2000                49.6   74.3   68.5
# y2005                41.3   71.2     68
# y2010                34.2   67.5     66
# y2015                31.5   64.9   64.1
#
# [15 rows x 241 columns]

# %%
datasetT = dataset.ix[0:]
datasetT.plot?

# %%
dataset.plot(x = kind='bar', stacked= True)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(dataset, figsize=(25,25), diagonal="density");
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
